# %% [markdown]
# <a href="https://colab.research.google.com/github/laurendunbar/ds1002-npr9wk/blob/main/Copy_of_week_15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework - Week 15
#
# Complete the following blocks as specified in the directions. Run each cell to return the desired output. Save your notebook back to your GitHub repository and submit the GitHub URL to your notebook for review.

# %% [markdown]
# ## 1. Create Functions (4 pts)
#
# Create two functions in the cells below, according to the prompts given.

# %%
# create a function in R that:
#   1. takes a single integer as an input parameter
#   2. determines whether the integer is even or odd
#   3. returns a character statement "The integer <x> is even" or "The integer <x> is odd" (replace <x> with the actual input provided)
#
# then execute the function twice using two different input values, displaying even and odd results.

check_even_odd <- function(x) {
  if (x %% 2 == 0) {
    return(paste("The integer", x, "is even"))
  } else {
    return(paste("The integer", x, "is odd"))
  }
}

result1 <- check_even_odd(4)
result2 <- check_even_odd(7)

cat(result1, "\n")
cat(result2, "\n")
# Out:
# The integer 4 is even
# The integer 7 is odd

# %%
# create a function in R that:
#   1. takes 4 integer input parameters
#   2. returns the mean value of the inputs
#   3. has default values for the 4 input parameters, in case they are not provided when the function is called.
#
# then execute the function twice: once where you provide the input values, and once where you do not.

calculate_mean <- function(a = 0, b = 0, c = 0, d = 0) {
  mean_value <- mean(c(a, b, c, d))
  return(mean_value)
}

result_with_input <- calculate_mean(3, 6, 9, 12)
cat("Mean with input values:", result_with_input, "\n")

result_without_input <- calculate_mean()
cat("Mean without input values:", result_without_input, "\n")
# Out:
# Mean with input values: 7.5
# Mean without input values: 0

# %% [markdown]
# ## 2. Plot Data (4 pts)

# %% [markdown]
# In the cell below, write the code required to plot from the `msleep` sample data set.
#
# 1. Display only animals with body weights of 30 or greater.
# 2. Group the animals by `order`.
# 3. Display the mean `sleep_total` for each group in a bar plot.

# %%
data("msleep", package = "ggplot2")

filtered_data <- msleep[msleep$bodywt >= 30, ]

ggplot(filtered_data, aes(x = order, y = sleep_total, fill = order)) +
  geom_bar(stat = "summary", fun = "mean") +
  labs(title = "Mean Sleep Total by Order (Body Weight >= 30)",
       x = "Order",
       y = "Mean Sleep Total") +
  theme_minimal()

# %% [markdown]
# ## 3. Clean and Analyze Data Using R (4 pts)
#
# In the cells below use R to perform the following data cleaning steps on this file:
# https://raw.githubusercontent.com/nmagee/ds1002/main/data/social-media-users.csv
#
# 1. Remove any duplicate rows.
# 2. Remove any records where `last_login` or `birthdate` are empty.
# 3. Display only the records with the 10 highest `follower` counts.
# 4. Determine counts of users when grouped by continent.

# %%
smusers <- read.csv("/social_media_users.csv")
unique(smusers)
# Out:
#      username       full_name            birthdate
# 1    ckippen0       Clevey Kippen        5/1/1991
# 2    tgergler1      Tedi Gergler         10/5/1998
# 3    spomfrett2     Steffie Pomfrett
# 4    rphettis3      Ruddy Phettis        6/18/1984
# 5    ngilcriest4    Nico Gilcriest       10/11/1993
# 6    fhampson5      Farrell Hampson      11/7/1985
# 7    ttotman6       Tamqrah Totman       8/7/1986
# 8    bdennes7       Bonita Dennes
# 9    kgrigoryev8    Krishna Grigoryev    5/25/1990
# 10   mbathoe9       Mallissa Bathoe
# 11   hallensona     Hayward Allenson     3/15/1983
# 12   mchittockb     Myriam Chittock      1/26/1989
# 13   mfranzewitchc  Max Franzewitch      12/25/1997
# 14   aeasbyd        Alessandra Easby     1/5/1991
# 15   hschubarte     Hubert Schubart      11/23/1984
# 16   dleishmanf     Dyane Leishman       2/12/1990
# 17   scoilsg        Shayla Coils
# 18   bkrzysztofh    Bendick Krzysztof    10/19/1985
# 19   omarusiki      Otha Marusik         12/4/1992
# ...

# %%
subset(data, !(is.na(last_login) | is.na(birthdate) | last_login == "" | birthdate == ""))
# Out:
#      username        full_name            birthdate
# 1    ckippen0        Clevey Kippen        5/1/1991
# 2    tgergler1       Tedi Gergler         10/5/1998
# 4    rphettis3       Ruddy Phettis        6/18/1984
# 7    ttotman6        Tamqrah Totman       8/7/1986
# 9    kgrigoryev8     Krishna Grigoryev    5/25/1990
# 12   mchittockb      Myriam Chittock      1/26/1989
# 14   aeasbyd         Alessandra Easby     1/5/1991
# 16   dleishmanf      Dyane Leishman       2/12/1990
# 19   omarusiki       Otha Marusik         12/4/1992
# 21   sspenclayk      Scott Spenclay       12/7/1989
# 22   gklinckl        Georgetta Klinck     7/26/1996
# 23   rhollowm        Riccardo Hollow      1/18/1980
# 29   galdrins        Gerick Aldrin        7/31/1995
# 30   ddimmockt       Didi Dimmock         5/15/1985
# 31   fpythonu        Franz Python         4/5/1984
# 32   btutingv        Brod Tuting          11/10/1988
# 33   tcosgriffw      Tami Cosgriff        8/26/1997
# ...

# %%
head(smusers[order(-smusers$followers), ], 10)
# Out:
#      username      full_name        birthdate
# 721  lleckeyb6     Lynne Leckey     4/19/1998
# 681  spharoaha2    Staci Pharoah    9/2/1985
# 1270 dpagettqf     Des Pagett       4/1/1992
# 1050 cbraderkb     Cody Brader
# 818  djagerdv      Deeyn Jager
# 821  cduftondy     Celisse Dufton   8/24/1995
# 578  dbartalin77   Desiree Bartalin 8/23/1993
# 1136 grivardmp     Gwen Rivard      9/12/1982
# 659  mraggitt9g    Morgan Raggitt   11/16/1992
# 134  vshallcrass3p Vally Shallcrass 9/26/2002
#      email                              continent followers last_login
# 721  lleckeyb6@tripadvisor.com          SA        99977     3/14/2021
# 681  spharoaha2@sfgate.com              NA        99905     10/26/2023
# 1270 dpagettqf@360.cn                   NA        99854
# 1050 cbraderkb@lulu.com                 AF        99747     6/19/2021
# 818  djagerdv@posterous.com             AF        99731     4/7/2022
# 821  cduftondy@ox.ac.uk                 OC        99707     9/26/2021
# ...

# %%
library(dplyr)
counts <- data %>%
  group_by(continent) %>%
  summarise(count = n())
print(counts)
# Out:
# # A tibble: 7 × 2
#   continent count
#   <chr>     <int>
# 1 AF          127
# 2 AN            1
# 3 AS          260
# 4 EU          172
# 5 OC          187
# 6 SA          107
# 7 NA          464
